# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans

# %%
tracks_df = pd.read_csv('/Users/tariqgeorges/Documents/Riq Coding/SpotGenTrack/Data Sources/spotify_tracks.csv')

# %%
reduced_df = tracks_df[:1000]
pd.plotting.scatter_matrix(reduced_df[['danceability', 'instrumentalness', 'energy', 'tempo', 'valence']],figsize=(20,12))
# Out:
# array([[<AxesSubplot: xlabel='danceability', ylabel='danceability'>,
#         <AxesSubplot: xlabel='instrumentalness', ylabel='danceability'>,
#         <AxesSubplot: xlabel='energy', ylabel='danceability'>,
#         <AxesSubplot: xlabel='tempo', ylabel='danceability'>,
#         <AxesSubplot: xlabel='valence', ylabel='danceability'>],
#        [<AxesSubplot: xlabel='danceability', ylabel='instrumentalness'>,
#         <AxesSubplot: xlabel='instrumentalness', ylabel='instrumentalness'>,
#         <AxesSubplot: xlabel='energy', ylabel='instrumentalness'>,
#         <AxesSubplot: xlabel='tempo', ylabel='instrumentalness'>,
#         <AxesSubplot: xlabel='valence', ylabel='instrumentalness'>],
#        [<AxesSubplot: xlabel='danceability', ylabel='energy'>,
#         <AxesSubplot: xlabel='instrumentalness', ylabel='energy'>,
#         <AxesSubplot: xlabel='energy', ylabel='energy'>,
#         <AxesSubplot: xlabel='tempo', ylabel='energy'>,
# ...

# %%
reduced_df.corr()
# Out:
# /var/folders/19/qvxbtx2j0930vt590g25785m0000gn/T/ipykernel_31772/3857884089.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   reduced_df.corr()
#                   Unnamed: 0  acousticness  danceability  disc_number  \
# Unnamed: 0          1.000000     -0.090561     -0.067619    -0.030364
# acousticness       -0.090561      1.000000     -0.303135     0.099272
# danceability       -0.067619     -0.303135      1.000000    -0.114091
# disc_number        -0.030364      0.099272     -0.114091     1.000000
# duration_ms        -0.092055      0.240985     -0.191136     0.087547
# energy              0.033299     -0.709649      0.259135    -0.102494
# instrumentalness    0.020395      0.208221     -0.457904     0.093065
# key                 0.033754     -0.041006      0.062352     0.020296
# ...

# %%
model = KMeans(n_clusters=6)
model.fit(tracks_df[['energy', 'valence', 'danceability', 'instrumentalness', 'tempo']])
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=6)
